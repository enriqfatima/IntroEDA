# %% [markdown]
# # COGS 118B - Data Wrangling

# %% [markdown]
# # Names
#
#
# - Ana Maria Baboescu
# - Bradley Grace
# - Fatima Enriquez
# - Lucy Giang
# - Stephanie Frianeza

# %% [markdown]
# # Imported Libraries
# Feel free to add any necessary libraries

# %%
import pandas as pd
import numpy as np
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.0' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # FMA - Bradley
# Below code displays the updated dataset with the wanted variables

# %% [markdown]
# # Spotify - Lucy
# Below code displays the updated dataset with the wanted variables

# %% [markdown]
# # 500 Greatest Songs - Fatima
# Below code displays the updated dataset with the wanted variables

# %%
df_top_500 = pd.read_csv('Top 500 Songs.csv',encoding='Latin 1')
df_top_500 = df_top_500[["title", "description", "artist"]] 
df_top_500.isnull().sum().sum() #no missing values (yay!) 
df_top_500
# Out:
#                               title  \
# 0              Like a Rolling Stone
# 1    (I Can't Get No) Satisfaction'
# 2                           Imagine
# 3                   What's Going On
# 4                           Respect
# ..                              ...
# 495                          Heroin
# 496              Leader of the Pack
# 497                   Pressure Drop
# 498                 Come As You Are
# 499                  I Got You Babe
#
#                                            description                  artist
# 0    "I wrote it. I didn't fail. It was straight," ...               Bob Dylan
# 1    "It's the riff heard round the world," says St...      The Rolling Stones
# 2    John Lennon wrote "Imagine," his greatest musi...             John Lennon
# 3    "What's Going On" is an exquisite plea for pea...             Marvin Gaye
# 4    Otis Redding wrote "Respect" and recorded it f...         Aretha Franklin
# ..                                                 ...                     ...
# 495  This seven-minute, two-chord track spiked out ...  The Velvet Underground
# 496  Morton found the inspiration for this song at ...         The Shangri-Las
# 497  Toots and the Maytals were already reggae star...   Toots and the Maytals
# 498  "It's just about people and what they're expec...                 Nirvana
# 499  Late one night, while Sonny and Cher were livi...          Sonny and Cher
#
# [500 rows x 3 columns]

# %% [markdown]
# # Prediction of Music - Ana & Stephanie
# Below code displays the updated dataset with the wanted variables

# %%
pred_Music = pd.read_csv('music_genre.csv')

# subset with wanted variables
edited_pred_Music = pred_Music[["artist_name", "track_name", "acousticness", "danceability", 
                                "instrumentalness", "liveness", "loudness", "mode", "speechiness", 
                                "tempo", "valence", "music_genre"]]

# if want to rename columns (for later reference)
# df = pd.DataFrame.rename(columns={"A" = "a", "B" = "b"})

# checked and got rid of duplicates
edited_pred_Music.drop_duplicates("track_name")
edited_pred_Music
# Out:
#                 artist_name                track_name  acousticness  \
# 0                  Röyksopp      Röyksopp's Night Out       0.00468
# 1      Thievery Corporation          The Shining Path       0.01270
# 2            Dillon Francis                 Hurricane       0.00306
# 3                  Dubloadz                     Nitro       0.02540
# 4               What So Not          Divide & Conquer       0.00465
# ...                     ...                       ...           ...
# 50000                 BEXEY                  GO GETTA       0.03340
# 50001             Roy Woods       Drama (feat. Drake)       0.15700
# 50002                Berner  Lovin' Me (feat. Smiggz)       0.00597
# 50003             The-Dream         Shawty Is Da Shit       0.08310
# 50004     Naughty By Nature            Hip Hop Hooray       0.10200
#
#        danceability  instrumentalness  liveness  loudness   mode  speechiness  \
# 0             0.652           0.79200     0.115    -5.201  Minor       0.0748
# 1             0.622           0.95000     0.124    -7.043  Minor       0.0300
# 2             0.620           0.01180     0.534    -4.617  Major       0.0345
# 3             0.774           0.00253     0.157    -4.498  Major       0.2390
# 4             0.638           0.90900     0.157    -6.266  Major       0.0413
# ...             ...               ...       ...       ...    ...          ...
# 50000         0.913           0.00000     0.119    -7.022  Major       0.2980
# 50001         0.709           0.00000     0.109    -9.814  Major       0.0550
# 50002         0.693           0.00000     0.143    -5.443  Major       0.1460
# 50003         0.782           0.00000     0.106    -5.016  Minor       0.0441
# 50004         0.862           0.00000     0.272   -13.652  Minor       0.1010
#
#                     tempo  valence music_genre
# 0                 100.889    0.759  Electronic
# 1      115.00200000000001    0.531  Electronic
# 2                 127.994    0.333  Electronic
# 3                 128.014    0.270  Electronic
# 4                 145.036    0.323  Electronic
# ...                   ...      ...         ...
# 50000   98.02799999999999    0.330     Hip-Hop
# 50001  122.04299999999999    0.113     Hip-Hop
# 50002             131.079    0.395     Hip-Hop
# 50003   75.88600000000001    0.354     Hip-Hop
# 50004   99.20100000000001    0.765     Hip-Hop
#
# [50005 rows x 12 columns]

# %% [markdown]
# # Compiled Data - Everyone
#
# Here we compile all the datasets together for Monday meeting

# %% [markdown]
# # EDA - TBD

# %% [markdown]
# # Program - TBD

# %% [markdown]
# # Footnotes
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Chillar, Snigdha et al. (May 2019) Music Genre Classification using Machine Learning Algorithms: A comparison. *International Research Journal of Engineering and Technology (IRJET)*. https://d1wqtxts1xzle7.cloudfront.net/59934287/IRJET-V6I517420190704-120568-1u4iafr-libre.pdf?1562308085=&response-content-disposition=inline%3B+filename%3DIRJET_Music_Genre_Classification_using_M.pdf&Expires=1708407619&Signature=WRJ6JnCTvv8fyWmo~A-SzVQ2DRT77pSZFX8tmlz7YCCB7J5ZMkrJpugkiwlJT7DoaCR-d2jI6IfGjgYXI9-EsJlVANQ~gJY04gUz9H4zkZG-HiyimSeXcAkK58Rqp06qgvlu-yx5zcM1wNxrnhgASBQEvVBkhyQMxETbkgtLYzw40gKVZFeioo0Qjj7aqC-YDzGwlzlnXhNss4xlBsBj7PdyTFgGu2cM8ky8g3XsqA1yIIuiO4cr0SEcCJU8orRATVTpB388Nud0GvNiGOz6DAhpoCBLEqrsYxFHk2jOut7x1TPs91ECXgG1SwjPE03vlYoeAMEkdV5pasBm1yZDeQ__&Key-Pair-Id=APKAJLOHF5GGSLRBV4ZA
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Bahuleyan, Hareesh( 3 April 2018) Music Genre Classification using Machine Learning Techniques. Cornell University. https://doi.org/10.48550/arXiv.1804.01149
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Wohlwend, Brandon (23 July 2023) Decision Tree, Random Forest, and XGBoost: An Exploration into the Heart of Machine Learning. Medium. https://medium.com/@brandon93.w/decision-tree-random-forest-and-xgboost-an-exploration-into-the-heart-of-machine-learning-90dc212f4948#:~:text=Random%20Forests%20build%20on%20this,that%20often%20outperforms%20many%20others.
